# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import wandb
wandb.login()

# %%
# skip if cloned already
# !git clone https://github.com/state-spaces/s4.git /content/drive/MyDrive/ceng501/codes/s4-main # different name to prevent overwriting change to s4-main

# %%
# %cd /content/drive/MyDrive/ceng501/codes/s4-main
# !ls

# %%
# !pip install -r requirements.txt

# %%
# !pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata
# !pip3 install torch==2.3.0 torchaudio torchvision torchtext==0.18.0 torchdata

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU available: {torch.cuda.is_available()}")
print(f"GPU name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'No GPU'}")

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)

# %%
# !nvidia-smi

# %%
# !touch train_log.txt
# !touch retrain_log.txt

# %%
# !python -u -m train experiment=lra/old/transformer-lra-listops > train_log.txt
